# %%
from pgmpy.models import BayesianModel

# %%
cancer_model=BayesianModel([('Pollution','Cancer'),('Smoker','Cancer'),('Cancer','Xray'),('Cancer','Dyspnoea')])

# %%
cancer_model.nodes()
# Out:
# NodeView(('Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea'))

# %%
cancer_model.edges()
# Out:
# OutEdgeView([('Pollution', 'Cancer'), ('Cancer', 'Xray'), ('Cancer', 'Dyspnoea'), ('Smoker', 'Cancer')])

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD
cpd_poll=TabularCPD(variable='Pollution',variable_card=2,values=[[0.9],[0.1]])
cpd_smoke=TabularCPD(variable='Smoker',variable_card=2,values=[[0.3],[0.7]])
cpd_cancer=TabularCPD(variable='Cancer',variable_card=2,values=[[0.03,0.05,0.001,0.02],[0.97,0.95,0.999,0.98]],evidence=['Smoker','Pollution'],evidence_card=[2,2])
cpd_xray=TabularCPD(variable='Xray',variable_card=2,values=[[0.9,0.2],[0.1,0.8]],evidence=['Cancer'],evidence_card=[2])
cpd_dysp=TabularCPD(variable='Dyspnoea',variable_card=2,values=[[0.65,0.3],[0.35,0.7]],evidence=['Cancer'],evidence_card=[2])

# %%
cancer_model.add_cpds(cpd_poll,cpd_smoke,cpd_cancer,cpd_xray,cpd_dysp)

# %%
cancer_model.check_model()
# Out:
# True

# %%
cancer_model.is_active_trail('Pollution','Smoker')
cancer_model.is_active_trail('Pollution','Smoker',observed=['Cancer'])
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x3c8c2f0>,
#  <TabularCPD representing P(Smoker:2) at 0x3c8c250>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x3c8c310>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x3c8c330>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x3c8c270>]

# %%
print(cancer_model.get_cpds('Pollution'))
# Out:
# ╒═════════════╤═════╕
# │ Pollution_0 │ 0.9 │
# ├─────────────┼─────┤
# │ Pollution_1 │ 0.1 │
# ╘═════════════╧═════╛

# %%
print(cancer_model.get_cpds('Smoker'))
# Out:
# ╒══════════╤═════╕
# │ Smoker_0 │ 0.3 │
# ├──────────┼─────┤
# │ Smoker_1 │ 0.7 │
# ╘══════════╧═════╛

# %%
print(cancer_model.get_cpds('Xray'))
# Out:
# ╒════════╤══════════╤══════════╕
# │ Cancer │ Cancer_0 │ Cancer_1 │
# ├────────┼──────────┼──────────┤
# │ Xray_0 │ 0.9      │ 0.2      │
# ├────────┼──────────┼──────────┤
# │ Xray_1 │ 0.1      │ 0.8      │
# ╘════════╧══════════╧══════════╛

# %%
print(cancer_model.get_cpds('Dyspnoea'))
# Out:
# ╒════════════╤══════════╤══════════╕
# │ Cancer     │ Cancer_0 │ Cancer_1 │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_0 │ 0.65     │ 0.3      │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_1 │ 0.35     │ 0.7      │
# ╘════════════╧══════════╧══════════╛

# %%
print(cancer_model.get_cpds('Cancer'))
# Out:
# ╒═══════════╤═════════════╤═════════════╤═════════════╤═════════════╕
# │ Smoker    │ Smoker_0    │ Smoker_0    │ Smoker_1    │ Smoker_1    │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Pollution │ Pollution_0 │ Pollution_1 │ Pollution_0 │ Pollution_1 │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_0  │ 0.03        │ 0.05        │ 0.001       │ 0.02        │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_1  │ 0.97        │ 0.95        │ 0.999       │ 0.98        │
# ╘═══════════╧═════════════╧═════════════╧═════════════╧═════════════╛

# %%
cancer_model.local_independencies('Xray')
# Out:
# (Xray _|_ Dyspnoea, Pollution, Smoker | Cancer)

# %%
cancer_model.local_independencies('Pollution')
# Out:
# (Pollution _|_ Dyspnoea, Cancer, Smoker, Xray)

# %%
cancer_model.local_independencies('Smoker')
# Out:
# (Smoker _|_ Dyspnoea, Pollution, Cancer, Xray)

# %%
cancer_model.local_independencies('Dyspnoea')
# Out:
# (Dyspnoea _|_ Pollution, Smoker, Xray | Cancer)

# %%
cancer_model.local_independencies('Cancer')
# Out:
# (Cancer _|_ Dyspnoea, Xray | Pollution, Smoker)

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Dyspnoea, Xray | Cancer)
# (Pollution _|_ Xray | Dyspnoea, Cancer)
# (Pollution _|_ Dyspnoea, Xray | Smoker, Cancer)
# (Pollution _|_ Dyspnoea | Xray, Cancer)
# (Pollution _|_ Xray | Dyspnoea, Smoker, Cancer)
# (Pollution _|_ Dyspnoea | Xray, Smoker, Cancer)
# (Smoker _|_ Pollution)
# (Smoker _|_ Dyspnoea, Xray | Cancer)
# (Smoker _|_ Xray | Dyspnoea, Cancer)
# (Smoker _|_ Dyspnoea, Xray | Pollution, Cancer)
# (Smoker _|_ Dyspnoea | Xray, Cancer)
# (Smoker _|_ Xray | Dyspnoea, Pollution, Cancer)
# (Smoker _|_ Dyspnoea | Pollution, Xray, Cancer)
# (Xray _|_ Dyspnoea, Pollution, Smoker | Cancer)
# (Xray _|_ Pollution, Smoker | Dyspnoea, Cancer)
# (Xray _|_ Dyspnoea, Smoker | Pollution, Cancer)
# (Xray _|_ Dyspnoea, Pollution | Smoker, Cancer)
# (Xray _|_ Smoker | Dyspnoea, Pollution, Cancer)
# (Xray _|_ Pollution | Dyspnoea, Smoker, Cancer)
# (Xray _|_ Dyspnoea | Pollution, Smoker, Cancer)
# (Dyspnoea _|_ Pollution, Smoker, Xray | Cancer)
# (Dyspnoea _|_ Smoker, Xray | Pollution, Cancer)
# (Dyspnoea _|_ Pollution, Xray | Smoker, Cancer)
# (Dyspnoea _|_ Pollution, Smoker | Xray, Cancer)
# (Dyspnoea _|_ Xray | Pollution, Smoker, Cancer)
# (Dyspnoea _|_ Smoker | Pollution, Xray, Cancer)
# (Dyspnoea _|_ Pollution | Xray, Smoker, Cancer)

# %%
from pgmpy.inference import VariableElimination

# %%
cancer_infer=VariableElimination(cancer_model)

# %%
q=cancer_infer.query(variables=['Cancer'],evidence={'Smoker':1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛
# c:\users\is-lab\appdata\local\programs\python\python37-32\lib\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]

# %%
q=cancer_infer.query(variables=['Cancer'],evidence={'Smoker':1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛

# %%
q=cancer_infer.query(variables=['Cancer'],evidence={'Smoker':1,'Pollution':1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0200 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9800 │
# ╘══════════╧═══════════════╛

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import pandas as pd

# %%
Cleveland_data_URL='http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'

# %%
np.set_printoptions(threshold=np.nan)

# %%
names=['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','heartdisease']

# %%
heartDisease=pd.read_csv(urlopen(Cleveland_data_URL),names=names)

# %%
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease['ca']

# %%
 del heartDisease['slope']

# %%
del heartDisease['thal']

# %%
del heartDisease['oldpeak']

# %%
heartDisease=heartDisease.replace('?',np.nan)
heartDisease.dtypes
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator,BayesianEstimator

# %%
model=BayesianModel([('age','trestbps'),('age','fbs'),('sex','trestbps'),('sex','trestbps'),('exang','trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])

# %%
model.fit(heartDisease,estimator=MaximumLikelihoodEstimator)
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# ╒═════════╤════════════╕
# │ age(28) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(29) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(30) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(31) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(32) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(33) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(34) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(35) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(36) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(37) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(38) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(39) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(40) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(41) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(42) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(43) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(44) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(45) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(46) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(47) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(48) │ 0.0613027  │
# ├─────────┼────────────┤
# │ age(49) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(50) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(51) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(52) │ 0.0574713  │
# ├─────────┼────────────┤
# │ age(53) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(54) │ 0.0842912  │
# ├─────────┼────────────┤
# │ age(55) │ 0.0536398  │
# ├─────────┼────────────┤
# │ age(56) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(57) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(58) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(59) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(60) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(61) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(62) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(63) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(65) │ 0.0114943  │
# ├─────────┼────────────┤
# │ age(66) │ 0          │
# ╘═════════╧════════════╛
# ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006535947712418301 │ 0.006535947712418301 │
# ╘══════════════╧══════════════════════╧══════════════════════╛
# ╒════════╤══════════╕
# │ sex(0) │ 0.264368 │
# ├────────┼──────────┤
# │ sex(1) │ 0.735632 │
# ╘════════╧══════════╛
# (age _|_ exang, sex)
# (age _|_ exang | sex)
# (age _|_ exang, sex | fbs)
# (age _|_ restecg, chol, thalach | heartdisease)
# (age _|_ sex | exang)
# (age _|_ heartdisease, chol, restecg, thalach | trestbps, fbs)
# (age _|_ restecg, chol, thalach | trestbps, heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ restecg, chol, thalach | heartdisease, sex)
# (age _|_ restecg, chol, thalach | heartdisease, fbs)
# (age _|_ sex | exang, fbs)
# (age _|_ restecg, thalach | heartdisease, chol)
# (age _|_ restecg, chol | heartdisease, thalach)
# (age _|_ chol, thalach | heartdisease, restecg)
# (age _|_ restecg, chol, thalach | heartdisease, exang)
# (age _|_ heartdisease, chol, restecg, thalach | trestbps, fbs, sex)
# (age _|_ restecg, chol, thalach | trestbps, sex, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, fbs, heartdisease)
# (age _|_ heartdisease, restecg, thalach | trestbps, fbs, chol)
# (age _|_ heartdisease, chol, restecg | trestbps, fbs, thalach)
# (age _|_ heartdisease, chol, thalach | trestbps, fbs, restecg)
# (age _|_ heartdisease, chol, restecg, thalach | trestbps, exang, fbs)
# (age _|_ restecg, thalach | trestbps, chol, heartdisease)
# (age _|_ restecg, chol | trestbps, heartdisease, thalach)
# (age _|_ chol, thalach | trestbps, restecg, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, exang, heartdisease)
# (age _|_ restecg, chol, thalach | heartdisease, fbs, sex)
# (age _|_ restecg, thalach | heartdisease, chol, sex)
# (age _|_ restecg, chol | heartdisease, sex, thalach)
# (age _|_ chol, thalach | heartdisease, restecg, sex)
# (age _|_ restecg, chol, thalach | heartdisease, exang, sex)
# (age _|_ restecg, thalach | heartdisease, fbs, chol)
# (age _|_ restecg, chol | heartdisease, fbs, thalach)
# (age _|_ chol, thalach | heartdisease, fbs, restecg)
# (age _|_ restecg, chol, thalach | heartdisease, exang, fbs)
# (age _|_ restecg | heartdisease, chol, thalach)
# (age _|_ thalach | heartdisease, chol, restecg)
# (age _|_ restecg, thalach | heartdisease, exang, chol)
# (age _|_ chol | heartdisease, restecg, thalach)
# (age _|_ restecg, chol | heartdisease, exang, thalach)
# (age _|_ chol, thalach | heartdisease, exang, restecg)
# (age _|_ restecg, chol, thalach | trestbps, fbs, sex, heartdisease)
# (age _|_ heartdisease, restecg, thalach | trestbps, fbs, chol, sex)
# (age _|_ heartdisease, chol, restecg | trestbps, fbs, sex, thalach)
# (age _|_ heartdisease, chol, thalach | trestbps, restecg, fbs, sex)
# (age _|_ heartdisease, chol, restecg, thalach | trestbps, exang, fbs, sex)
# (age _|_ restecg, thalach | trestbps, chol, sex, heartdisease)
# (age _|_ restecg, chol | trestbps, thalach, sex, heartdisease)
# (age _|_ chol, thalach | trestbps, restecg, sex, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, exang, sex, heartdisease)
# (age _|_ restecg, thalach | trestbps, fbs, chol, heartdisease)
# (age _|_ restecg, chol | trestbps, fbs, heartdisease, thalach)
# (age _|_ chol, thalach | trestbps, restecg, fbs, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, exang, fbs, heartdisease)
# (age _|_ heartdisease, restecg | trestbps, fbs, chol, thalach)
# (age _|_ heartdisease, thalach | trestbps, fbs, chol, restecg)
# (age _|_ heartdisease, restecg, thalach | trestbps, exang, fbs, chol)
# (age _|_ heartdisease, chol | trestbps, fbs, restecg, thalach)
# (age _|_ heartdisease, chol, restecg | trestbps, exang, fbs, thalach)
# (age _|_ heartdisease, chol, thalach | trestbps, exang, fbs, restecg)
# (age _|_ restecg | trestbps, chol, heartdisease, thalach)
# (age _|_ thalach | trestbps, restecg, chol, heartdisease)
# (age _|_ restecg, thalach | trestbps, exang, chol, heartdisease)
# (age _|_ chol | trestbps, restecg, heartdisease, thalach)
# (age _|_ restecg, chol | trestbps, exang, heartdisease, thalach)
# (age _|_ chol, thalach | trestbps, exang, restecg, heartdisease)
# (age _|_ restecg, thalach | heartdisease, fbs, chol, sex)
# (age _|_ restecg, chol | heartdisease, fbs, sex, thalach)
# (age _|_ chol, thalach | heartdisease, restecg, fbs, sex)
# (age _|_ restecg, chol, thalach | heartdisease, exang, fbs, sex)
# (age _|_ restecg | heartdisease, chol, sex, thalach)
# (age _|_ thalach | heartdisease, restecg, chol, sex)
# (age _|_ restecg, thalach | heartdisease, exang, chol, sex)
# (age _|_ chol | heartdisease, restecg, sex, thalach)
# (age _|_ restecg, chol | heartdisease, exang, sex, thalach)
# (age _|_ chol, thalach | heartdisease, exang, restecg, sex)
# (age _|_ restecg | heartdisease, fbs, chol, thalach)
# (age _|_ thalach | heartdisease, fbs, chol, restecg)
# (age _|_ restecg, thalach | heartdisease, exang, fbs, chol)
# (age _|_ chol | heartdisease, fbs, restecg, thalach)
# (age _|_ restecg, chol | heartdisease, exang, fbs, thalach)
# (age _|_ chol, thalach | heartdisease, exang, fbs, restecg)
# (age _|_ restecg | heartdisease, exang, chol, thalach)
# (age _|_ thalach | heartdisease, exang, chol, restecg)
# (age _|_ chol | heartdisease, exang, restecg, thalach)
# (age _|_ restecg, thalach | trestbps, sex, fbs, heartdisease, chol)
# (age _|_ restecg, chol | trestbps, sex, fbs, heartdisease, thalach)
# (age _|_ chol, thalach | trestbps, sex, fbs, heartdisease, restecg)
# (age _|_ restecg, chol, thalach | trestbps, sex, fbs, heartdisease, exang)
# (age _|_ heartdisease, restecg | trestbps, sex, fbs, chol, thalach)
# (age _|_ heartdisease, thalach | trestbps, sex, fbs, chol, restecg)
# (age _|_ heartdisease, restecg, thalach | trestbps, sex, fbs, chol, exang)
# (age _|_ heartdisease, chol | trestbps, sex, fbs, thalach, restecg)
# (age _|_ heartdisease, chol, restecg | trestbps, sex, fbs, thalach, exang)
# (age _|_ heartdisease, chol, thalach | trestbps, sex, fbs, restecg, exang)
# (age _|_ restecg | trestbps, sex, heartdisease, chol, thalach)
# (age _|_ thalach | trestbps, sex, heartdisease, chol, restecg)
# (age _|_ restecg, thalach | trestbps, sex, heartdisease, chol, exang)
# (age _|_ chol | trestbps, sex, heartdisease, thalach, restecg)
# (age _|_ restecg, chol | trestbps, sex, heartdisease, thalach, exang)
# (age _|_ chol, thalach | trestbps, sex, heartdisease, restecg, exang)
# (age _|_ restecg | trestbps, fbs, heartdisease, chol, thalach)
# (age _|_ thalach | trestbps, fbs, heartdisease, chol, restecg)
# (age _|_ restecg, thalach | trestbps, fbs, heartdisease, chol, exang)
# (age _|_ chol | trestbps, fbs, heartdisease, thalach, restecg)
# (age _|_ restecg, chol | trestbps, fbs, heartdisease, thalach, exang)
# (age _|_ chol, thalach | trestbps, fbs, heartdisease, restecg, exang)
# (age _|_ heartdisease | trestbps, fbs, chol, thalach, restecg)
# (age _|_ heartdisease, restecg | trestbps, fbs, chol, thalach, exang)
# (age _|_ heartdisease, thalach | trestbps, fbs, chol, restecg, exang)
# (age _|_ heartdisease, chol | trestbps, fbs, thalach, restecg, exang)
# (age _|_ restecg | trestbps, heartdisease, chol, thalach, exang)
# (age _|_ thalach | trestbps, heartdisease, chol, restecg, exang)
# (age _|_ chol | trestbps, heartdisease, thalach, restecg, exang)
# (age _|_ restecg | sex, fbs, heartdisease, chol, thalach)
# (age _|_ thalach | sex, fbs, heartdisease, chol, restecg)
# (age _|_ restecg, thalach | sex, fbs, heartdisease, chol, exang)
# (age _|_ chol | sex, fbs, heartdisease, thalach, restecg)
# (age _|_ restecg, chol | sex, fbs, heartdisease, thalach, exang)
# (age _|_ chol, thalach | sex, fbs, heartdisease, restecg, exang)
# (age _|_ restecg | sex, heartdisease, chol, thalach, exang)
# (age _|_ thalach | sex, heartdisease, chol, restecg, exang)
# (age _|_ chol | sex, heartdisease, thalach, restecg, exang)
# (age _|_ restecg | fbs, heartdisease, chol, thalach, exang)
# (age _|_ thalach | fbs, heartdisease, chol, restecg, exang)
# (age _|_ chol | fbs, heartdisease, thalach, restecg, exang)
# (age _|_ restecg | trestbps, sex, fbs, heartdisease, chol, thalach)
# (age _|_ thalach | trestbps, sex, fbs, heartdisease, chol, restecg)
# (age _|_ restecg, thalach | trestbps, sex, fbs, heartdisease, chol, exang)
# (age _|_ chol | trestbps, sex, fbs, heartdisease, thalach, restecg)
# (age _|_ restecg, chol | trestbps, sex, fbs, heartdisease, thalach, exang)
# (age _|_ chol, thalach | trestbps, sex, fbs, heartdisease, restecg, exang)
# (age _|_ heartdisease | trestbps, sex, fbs, chol, thalach, restecg)
# (age _|_ heartdisease, restecg | trestbps, sex, fbs, chol, thalach, exang)
# (age _|_ heartdisease, thalach | trestbps, sex, fbs, chol, restecg, exang)
# (age _|_ heartdisease, chol | trestbps, sex, fbs, thalach, restecg, exang)
# (age _|_ restecg | trestbps, sex, heartdisease, chol, thalach, exang)
# (age _|_ thalach | trestbps, sex, heartdisease, chol, restecg, exang)
# (age _|_ chol | trestbps, sex, heartdisease, thalach, restecg, exang)
# (age _|_ restecg | trestbps, fbs, heartdisease, chol, thalach, exang)
# (age _|_ thalach | trestbps, fbs, heartdisease, chol, restecg, exang)
# (age _|_ chol | trestbps, fbs, heartdisease, thalach, restecg, exang)
# (age _|_ heartdisease | trestbps, fbs, chol, thalach, restecg, exang)
# (age _|_ restecg | sex, fbs, heartdisease, chol, thalach, exang)
# (age _|_ thalach | sex, fbs, heartdisease, chol, restecg, exang)
# (age _|_ chol | sex, fbs, heartdisease, thalach, restecg, exang)
# (age _|_ restecg | trestbps, sex, fbs, heartdisease, chol, thalach, exang)
# (age _|_ thalach | trestbps, sex, fbs, heartdisease, chol, restecg, exang)
# (age _|_ chol | trestbps, sex, fbs, heartdisease, thalach, restecg, exang)
# (age _|_ heartdisease | trestbps, sex, fbs, chol, thalach, restecg, exang)
# (trestbps _|_ fbs | age)
# (trestbps _|_ restecg, chol, thalach | heartdisease)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs)
# (trestbps _|_ restecg, thalach | heartdisease, chol)
# (trestbps _|_ restecg, chol | heartdisease, thalach)
# (trestbps _|_ chol, thalach | heartdisease, restecg)
# (trestbps _|_ restecg, chol, thalach | heartdisease, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, sex)
# (trestbps _|_ fbs | age, exang, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs, sex)
# (trestbps _|_ restecg, thalach | heartdisease, chol, sex)
# (trestbps _|_ restecg, chol | heartdisease, sex, thalach)
# (trestbps _|_ chol, thalach | heartdisease, restecg, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, exang, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, fbs)
# (trestbps _|_ restecg, thalach | heartdisease, age, chol)
# (trestbps _|_ restecg, chol | heartdisease, age, thalach)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, exang)
# (trestbps _|_ restecg, thalach | heartdisease, fbs, chol)
# (trestbps _|_ restecg, chol | heartdisease, fbs, thalach)
# (trestbps _|_ chol, thalach | heartdisease, fbs, restecg)
# (trestbps _|_ restecg, chol, thalach | heartdisease, exang, fbs)
# (trestbps _|_ restecg | heartdisease, chol, thalach)
# (trestbps _|_ thalach | heartdisease, chol, restecg)
# (trestbps _|_ restecg, thalach | heartdisease, exang, chol)
# (trestbps _|_ chol | heartdisease, restecg, thalach)
# (trestbps _|_ restecg, chol | heartdisease, exang, thalach)
# (trestbps _|_ chol, thalach | heartdisease, exang, restecg)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, fbs, sex)
# (trestbps _|_ restecg, thalach | heartdisease, age, chol, sex)
# (trestbps _|_ restecg, chol | heartdisease, age, sex, thalach)
# (trestbps _|_ chol, thalach | heartdisease, age, restecg, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, exang, sex)
# (trestbps _|_ restecg, thalach | heartdisease, fbs, chol, sex)
# (trestbps _|_ restecg, chol | heartdisease, fbs, sex, thalach)
# (trestbps _|_ chol, thalach | heartdisease, restecg, fbs, sex)
# (trestbps _|_ restecg, chol, thalach | heartdisease, exang, fbs, sex)
# (trestbps _|_ restecg | heartdisease, chol, sex, thalach)
# (trestbps _|_ thalach | heartdisease, restecg, chol, sex)
# (trestbps _|_ restecg, thalach | heartdisease, exang, chol, sex)
# (trestbps _|_ chol | heartdisease, restecg, sex, thalach)
# (trestbps _|_ restecg, chol | heartdisease, exang, sex, thalach)
# (trestbps _|_ chol, thalach | heartdisease, exang, restecg, sex)
# (trestbps _|_ restecg, thalach | heartdisease, age, fbs, chol)
# (trestbps _|_ restecg, chol | heartdisease, age, fbs, thalach)
# (trestbps _|_ chol, thalach | heartdisease, age, fbs, restecg)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, exang, fbs)
# (trestbps _|_ restecg | heartdisease, age, chol, thalach)
# (trestbps _|_ thalach | heartdisease, age, chol, restecg)
# (trestbps _|_ restecg, thalach | heartdisease, age, exang, chol)
# (trestbps _|_ chol | heartdisease, age, restecg, thalach)
# (trestbps _|_ restecg, chol | heartdisease, age, exang, thalach)
# (trestbps _|_ chol, thalach | heartdisease, age, exang, restecg)
# (trestbps _|_ restecg | heartdisease, fbs, chol, thalach)
# (trestbps _|_ thalach | heartdisease, fbs, chol, restecg)
# (trestbps _|_ restecg, thalach | heartdisease, exang, fbs, chol)
# (trestbps _|_ chol | heartdisease, fbs, restecg, thalach)
# (trestbps _|_ restecg, chol | heartdisease, exang, fbs, thalach)
# (trestbps _|_ chol, thalach | heartdisease, exang, fbs, restecg)
# (trestbps _|_ restecg | heartdisease, exang, chol, thalach)
# (trestbps _|_ thalach | heartdisease, exang, chol, restecg)
# (trestbps _|_ chol | heartdisease, exang, restecg, thalach)
# (trestbps _|_ restecg, thalach | sex, age, fbs, heartdisease, chol)
# (trestbps _|_ restecg, chol | sex, age, fbs, heartdisease, thalach)
# (trestbps _|_ chol, thalach | sex, age, fbs, heartdisease, restecg)
# (trestbps _|_ restecg, chol, thalach | sex, age, fbs, heartdisease, exang)
# (trestbps _|_ restecg | sex, age, heartdisease, chol, thalach)
# (trestbps _|_ thalach | sex, age, heartdisease, chol, restecg)
# (trestbps _|_ restecg, thalach | sex, age, heartdisease, chol, exang)
# (trestbps _|_ chol | sex, age, heartdisease, thalach, restecg)
# (trestbps _|_ restecg, chol | sex, age, heartdisease, thalach, exang)
# (trestbps _|_ chol, thalach | sex, age, heartdisease, restecg, exang)
# (trestbps _|_ restecg | sex, fbs, heartdisease, chol, thalach)
# (trestbps _|_ thalach | sex, fbs, heartdisease, chol, restecg)
# (trestbps _|_ restecg, thalach | sex, fbs, heartdisease, chol, exang)
# (trestbps _|_ chol | sex, fbs, heartdisease, thalach, restecg)
# (trestbps _|_ restecg, chol | sex, fbs, heartdisease, thalach, exang)
# (trestbps _|_ chol, thalach | sex, fbs, heartdisease, restecg, exang)
# (trestbps _|_ restecg | sex, heartdisease, chol, thalach, exang)
# (trestbps _|_ thalach | sex, heartdisease, chol, restecg, exang)
# (trestbps _|_ chol | sex, heartdisease, thalach, restecg, exang)
# (trestbps _|_ restecg | age, fbs, heartdisease, chol, thalach)
# (trestbps _|_ thalach | age, fbs, heartdisease, chol, restecg)
# (trestbps _|_ restecg, thalach | age, fbs, heartdisease, chol, exang)
# (trestbps _|_ chol | age, fbs, heartdisease, thalach, restecg)
# (trestbps _|_ restecg, chol | age, fbs, heartdisease, thalach, exang)
# (trestbps _|_ chol, thalach | age, fbs, heartdisease, restecg, exang)
# (trestbps _|_ restecg | age, heartdisease, chol, thalach, exang)
# (trestbps _|_ thalach | age, heartdisease, chol, restecg, exang)
# (trestbps _|_ chol | age, heartdisease, thalach, restecg, exang)
# (trestbps _|_ restecg | fbs, heartdisease, chol, thalach, exang)
# (trestbps _|_ thalach | fbs, heartdisease, chol, restecg, exang)
# (trestbps _|_ chol | fbs, heartdisease, thalach, restecg, exang)
# (trestbps _|_ restecg | sex, age, fbs, heartdisease, chol, thalach)
# (trestbps _|_ thalach | sex, age, fbs, heartdisease, chol, restecg)
# (trestbps _|_ restecg, thalach | sex, age, fbs, heartdisease, chol, exang)
# (trestbps _|_ chol | sex, age, fbs, heartdisease, thalach, restecg)
# (trestbps _|_ restecg, chol | sex, age, fbs, heartdisease, thalach, exang)
# (trestbps _|_ chol, thalach | sex, age, fbs, heartdisease, restecg, exang)
# (trestbps _|_ restecg | sex, age, heartdisease, chol, thalach, exang)
# (trestbps _|_ thalach | sex, age, heartdisease, chol, restecg, exang)
# (trestbps _|_ chol | sex, age, heartdisease, thalach, restecg, exang)
# (trestbps _|_ restecg | sex, fbs, heartdisease, chol, thalach, exang)
# (trestbps _|_ thalach | sex, fbs, heartdisease, chol, restecg, exang)
# (trestbps _|_ chol | sex, fbs, heartdisease, thalach, restecg, exang)
# (trestbps _|_ restecg | age, fbs, heartdisease, chol, thalach, exang)
# (trestbps _|_ thalach | age, fbs, heartdisease, chol, restecg, exang)
# (trestbps _|_ chol | age, fbs, heartdisease, thalach, restecg, exang)
# (trestbps _|_ restecg | sex, age, fbs, heartdisease, chol, thalach, exang)
# (trestbps _|_ thalach | sex, age, fbs, heartdisease, chol, restecg, exang)
# (trestbps _|_ chol | sex, age, fbs, heartdisease, thalach, restecg, exang)
# (fbs _|_ exang, sex)
# (fbs _|_ exang | sex)
# (fbs _|_ trestbps, exang, sex | age)
# (fbs _|_ restecg, chol, thalach | heartdisease)
# (fbs _|_ sex | exang)
# (fbs _|_ exang, sex | trestbps, age)
# (fbs _|_ restecg, chol, thalach | trestbps, heartdisease)
# (fbs _|_ trestbps, exang | age, sex)
# (fbs _|_ restecg, chol, thalach | heartdisease, sex)
# (fbs _|_ restecg, chol, thalach | heartdisease, age)
# (fbs _|_ trestbps, sex | age, exang)
# (fbs _|_ restecg, thalach | heartdisease, chol)
# (fbs _|_ restecg, chol | heartdisease, thalach)
# (fbs _|_ chol, thalach | heartdisease, restecg)
# (fbs _|_ restecg, chol, thalach | heartdisease, exang)
# (fbs _|_ exang | trestbps, age, sex)
# (fbs _|_ restecg, chol, thalach | trestbps, sex, heartdisease)
# (fbs _|_ chol, sex, thalach, restecg, exang | trestbps, age, heartdisease)
# (fbs _|_ exang, sex | trestbps, age, chol)
# (fbs _|_ exang, sex | trestbps, age, thalach)
# (fbs _|_ exang, sex | trestbps, age, restecg)
# (fbs _|_ sex | trestbps, age, exang)
# (fbs _|_ restecg, thalach | trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol | trestbps, heartdisease, thalach)
# (fbs _|_ chol, thalach | trestbps, restecg, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, exang, heartdisease)
# (fbs _|_ restecg, chol, thalach | heartdisease, age, sex)
# (fbs _|_ trestbps | age, exang, sex)
# (fbs _|_ restecg, thalach | heartdisease, chol, sex)
# (fbs _|_ restecg, chol | heartdisease, sex, thalach)
# (fbs _|_ chol, thalach | heartdisease, restecg, sex)
# (fbs _|_ restecg, chol, thalach | heartdisease, exang, sex)
# (fbs _|_ restecg, thalach | heartdisease, age, chol)
# (fbs _|_ restecg, chol | heartdisease, age, thalach)
# (fbs _|_ chol, thalach | heartdisease, age, restecg)
# (fbs _|_ restecg, chol, thalach | heartdisease, age, exang)
# (fbs _|_ restecg | heartdisease, chol, thalach)
# (fbs _|_ thalach | heartdisease, chol, restecg)
# (fbs _|_ restecg, thalach | heartdisease, exang, chol)
# (fbs _|_ chol | heartdisease, restecg, thalach)
# (fbs _|_ restecg, chol | heartdisease, exang, thalach)
# (fbs _|_ chol, thalach | heartdisease, exang, restecg)
# (fbs _|_ restecg, exang, chol, thalach | trestbps, age, sex, heartdisease)
# (fbs _|_ exang | trestbps, age, chol, sex)
# (fbs _|_ exang | trestbps, age, sex, thalach)
# (fbs _|_ exang | trestbps, age, restecg, sex)
# (fbs _|_ restecg, thalach | trestbps, chol, sex, heartdisease)
# (fbs _|_ restecg, chol | trestbps, thalach, sex, heartdisease)
# (fbs _|_ chol, thalach | trestbps, restecg, sex, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, exang, sex, heartdisease)
# (fbs _|_ restecg, exang, sex, thalach | trestbps, age, chol, heartdisease)
# (fbs _|_ restecg, exang, chol, sex | trestbps, age, heartdisease, thalach)
# (fbs _|_ exang, chol, sex, thalach | trestbps, age, restecg, heartdisease)
# (fbs _|_ restecg, chol, sex, thalach | trestbps, age, exang, heartdisease)
# (fbs _|_ exang, sex | trestbps, age, chol, thalach)
# (fbs _|_ exang, sex | trestbps, age, chol, restecg)
# (fbs _|_ sex | trestbps, age, exang, chol)
# (fbs _|_ exang, sex | trestbps, age, restecg, thalach)
# (fbs _|_ sex | trestbps, age, exang, thalach)
# (fbs _|_ sex | trestbps, age, exang, restecg)
# (fbs _|_ restecg | trestbps, chol, heartdisease, thalach)
# (fbs _|_ thalach | trestbps, restecg, chol, heartdisease)
# (fbs _|_ restecg, thalach | trestbps, exang, chol, heartdisease)
# (fbs _|_ chol | trestbps, restecg, heartdisease, thalach)
# (fbs _|_ restecg, chol | trestbps, exang, heartdisease, thalach)
# (fbs _|_ chol, thalach | trestbps, exang, restecg, heartdisease)
# (fbs _|_ restecg, thalach | heartdisease, age, chol, sex)
# (fbs _|_ restecg, chol | heartdisease, age, sex, thalach)
# (fbs _|_ chol, thalach | heartdisease, age, restecg, sex)
# (fbs _|_ restecg, chol, thalach | heartdisease, age, exang, sex)
# (fbs _|_ restecg | heartdisease, chol, sex, thalach)
# (fbs _|_ thalach | heartdisease, restecg, chol, sex)
# (fbs _|_ restecg, thalach | heartdisease, exang, chol, sex)
# (fbs _|_ chol | heartdisease, restecg, sex, thalach)
# (fbs _|_ restecg, chol | heartdisease, exang, sex, thalach)
# (fbs _|_ chol, thalach | heartdisease, exang, restecg, sex)
# (fbs _|_ restecg | heartdisease, age, chol, thalach)
# (fbs _|_ thalach | heartdisease, age, chol, restecg)
# (fbs _|_ restecg, thalach | heartdisease, age, exang, chol)
# (fbs _|_ chol | heartdisease, age, restecg, thalach)
# (fbs _|_ restecg, chol | heartdisease, age, exang, thalach)
# (fbs _|_ chol, thalach | heartdisease, age, exang, restecg)
# (fbs _|_ restecg | heartdisease, exang, chol, thalach)
# (fbs _|_ thalach | heartdisease, exang, chol, restecg)
# (fbs _|_ chol | heartdisease, exang, restecg, thalach)
# (fbs _|_ restecg, exang, thalach | trestbps, sex, age, heartdisease, chol)
# (fbs _|_ restecg, exang, chol | trestbps, sex, age, heartdisease, thalach)
# (fbs _|_ exang, chol, thalach | trestbps, sex, age, heartdisease, restecg)
# (fbs _|_ restecg, chol, thalach | trestbps, sex, age, heartdisease, exang)
# (fbs _|_ exang | trestbps, sex, age, chol, thalach)
# (fbs _|_ exang | trestbps, sex, age, chol, restecg)
# (fbs _|_ exang | trestbps, sex, age, thalach, restecg)
# (fbs _|_ restecg | trestbps, sex, heartdisease, chol, thalach)
# (fbs _|_ thalach | trestbps, sex, heartdisease, chol, restecg)
# (fbs _|_ restecg, thalach | trestbps, sex, heartdisease, chol, exang)
# (fbs _|_ chol | trestbps, sex, heartdisease, thalach, restecg)
# (fbs _|_ restecg, chol | trestbps, sex, heartdisease, thalach, exang)
# (fbs _|_ chol, thalach | trestbps, sex, heartdisease, restecg, exang)
# (fbs _|_ restecg, exang, sex | trestbps, age, heartdisease, chol, thalach)
# (fbs _|_ exang, sex, thalach | trestbps, age, heartdisease, chol, restecg)
# (fbs _|_ restecg, sex, thalach | trestbps, age, heartdisease, chol, exang)
# (fbs _|_ exang, chol, sex | trestbps, age, heartdisease, thalach, restecg)
# (fbs _|_ restecg, chol, sex | trestbps, age, heartdisease, thalach, exang)
# (fbs _|_ chol, sex, thalach | trestbps, age, heartdisease, restecg, exang)
# (fbs _|_ exang, sex | trestbps, age, chol, thalach, restecg)
# (fbs _|_ sex | trestbps, age, chol, thalach, exang)
# (fbs _|_ sex | trestbps, age, chol, restecg, exang)
# (fbs _|_ sex | trestbps, age, thalach, restecg, exang)
# (fbs _|_ restecg | trestbps, heartdisease, chol, thalach, exang)
# (fbs _|_ thalach | trestbps, heartdisease, chol, restecg, exang)
# (fbs _|_ chol | trestbps, heartdisease, thalach, restecg, exang)
# (fbs _|_ restecg | sex, age, heartdisease, chol, thalach)
# (fbs _|_ thalach | sex, age, heartdisease, chol, restecg)
# (fbs _|_ restecg, thalach | sex, age, heartdisease, chol, exang)
# (fbs _|_ chol | sex, age, heartdisease, thalach, restecg)
# (fbs _|_ restecg, chol | sex, age, heartdisease, thalach, exang)
# (fbs _|_ chol, thalach | sex, age, heartdisease, restecg, exang)
# (fbs _|_ restecg | sex, heartdisease, chol, thalach, exang)
# (fbs _|_ thalach | sex, heartdisease, chol, restecg, exang)
# (fbs _|_ chol | sex, heartdisease, thalach, restecg, exang)
# (fbs _|_ restecg | age, heartdisease, chol, thalach, exang)
# (fbs _|_ thalach | age, heartdisease, chol, restecg, exang)
# (fbs _|_ chol | age, heartdisease, thalach, restecg, exang)
# (fbs _|_ restecg, exang | trestbps, sex, age, heartdisease, chol, thalach)
# (fbs _|_ exang, thalach | trestbps, sex, age, heartdisease, chol, restecg)
# (fbs _|_ restecg, thalach | trestbps, sex, age, heartdisease, chol, exang)
# (fbs _|_ exang, chol | trestbps, sex, age, heartdisease, thalach, restecg)
# (fbs _|_ restecg, chol | trestbps, sex, age, heartdisease, thalach, exang)
# (fbs _|_ chol, thalach | trestbps, sex, age, heartdisease, restecg, exang)
# (fbs _|_ exang | trestbps, sex, age, chol, thalach, restecg)
# (fbs _|_ restecg | trestbps, sex, heartdisease, chol, thalach, exang)
# (fbs _|_ thalach | trestbps, sex, heartdisease, chol, restecg, exang)
# (fbs _|_ chol | trestbps, sex, heartdisease, thalach, restecg, exang)
# (fbs _|_ exang, sex | trestbps, age, heartdisease, chol, thalach, restecg)
# (fbs _|_ restecg, sex | trestbps, age, heartdisease, chol, thalach, exang)
# (fbs _|_ sex, thalach | trestbps, age, heartdisease, chol, restecg, exang)
# (fbs _|_ chol, sex | trestbps, age, heartdisease, thalach, restecg, exang)
# (fbs _|_ sex | trestbps, age, chol, thalach, restecg, exang)
# (fbs _|_ restecg | sex, age, heartdisease, chol, thalach, exang)
# (fbs _|_ thalach | sex, age, heartdisease, chol, restecg, exang)
# (fbs _|_ chol | sex, age, heartdisease, thalach, restecg, exang)
# (fbs _|_ exang | trestbps, sex, age, heartdisease, chol, thalach, restecg)
# (fbs _|_ restecg | trestbps, sex, age, heartdisease, chol, thalach, exang)
# (fbs _|_ thalach | trestbps, sex, age, heartdisease, chol, restecg, exang)
# (fbs _|_ chol | trestbps, sex, age, heartdisease, thalach, restecg, exang)
# (fbs _|_ sex | trestbps, age, heartdisease, chol, thalach, restecg, exang)
# (sex _|_ age, exang, fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ age, exang | fbs)
# (sex _|_ restecg, chol, thalach | heartdisease)
# (sex _|_ age, fbs | exang)
# (sex _|_ heartdisease, chol, thalach, restecg, fbs | trestbps, age)
# (sex _|_ heartdisease, chol, restecg, thalach | trestbps, fbs)
# (sex _|_ restecg, chol, thalach | trestbps, heartdisease)
# (sex _|_ exang | age, fbs)
# (sex _|_ restecg, chol, thalach | heartdisease, age)
# (sex _|_ fbs | age, exang)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs)
# (sex _|_ age | exang, fbs)
# (sex _|_ restecg, thalach | heartdisease, chol)
# (sex _|_ restecg, chol | heartdisease, thalach)
# (sex _|_ chol, thalach | heartdisease, restecg)
# (sex _|_ restecg, chol, thalach | heartdisease, exang)
# (sex _|_ heartdisease, chol, restecg, thalach | trestbps, age, fbs)
# (sex _|_ restecg, fbs, chol, thalach | trestbps, age, heartdisease)
# (sex _|_ heartdisease, fbs, restecg, thalach | trestbps, age, chol)
# (sex _|_ heartdisease, fbs, chol, restecg | trestbps, age, thalach)
# (sex _|_ heartdisease, fbs, chol, thalach | trestbps, age, restecg)
# (sex _|_ heartdisease, chol, thalach, restecg, fbs | trestbps, age, exang)
# (sex _|_ restecg, chol, thalach | trestbps, fbs, heartdisease)
# (sex _|_ heartdisease, restecg, thalach | trestbps, fbs, chol)
# ...
# (thalach _|_ restecg, exang, sex | trestbps, age, fbs, heartdisease, chol)
# (thalach _|_ exang, chol, sex | trestbps, age, fbs, heartdisease, restecg)
# (thalach _|_ restecg, chol, sex | trestbps, age, fbs, heartdisease, exang)
# (thalach _|_ exang, sex | trestbps, age, fbs, chol, restecg)
# (thalach _|_ sex | trestbps, age, fbs, chol, exang)
# (thalach _|_ sex | trestbps, age, fbs, restecg, exang)
# (thalach _|_ exang, fbs, sex | trestbps, age, heartdisease, chol, restecg)
# (thalach _|_ restecg, fbs, sex | trestbps, age, heartdisease, chol, exang)
# (thalach _|_ fbs, chol, sex | trestbps, age, heartdisease, restecg, exang)
# (thalach _|_ sex | trestbps, age, chol, restecg, exang)
# (thalach _|_ age, exang, sex | trestbps, fbs, heartdisease, chol, restecg)
# (thalach _|_ restecg, age, sex | trestbps, fbs, heartdisease, chol, exang)
# (thalach _|_ age, chol, sex | trestbps, fbs, heartdisease, restecg, exang)
# (thalach _|_ age, sex | trestbps, fbs, chol, restecg, exang)
# (thalach _|_ age, fbs, sex | trestbps, heartdisease, chol, restecg, exang)
# (thalach _|_ trestbps, exang, restecg | sex, age, fbs, heartdisease, chol)
# (thalach _|_ trestbps, exang, chol | sex, age, fbs, heartdisease, restecg)
# (thalach _|_ trestbps, chol, restecg | sex, age, fbs, heartdisease, exang)
# (thalach _|_ trestbps, exang, fbs | sex, age, heartdisease, chol, restecg)
# (thalach _|_ trestbps, fbs, restecg | sex, age, heartdisease, chol, exang)
# (thalach _|_ trestbps, fbs, chol | sex, age, heartdisease, restecg, exang)
# (thalach _|_ trestbps, age, exang | sex, fbs, heartdisease, chol, restecg)
# (thalach _|_ trestbps, age, restecg | sex, fbs, heartdisease, chol, exang)
# (thalach _|_ trestbps, age, chol | sex, fbs, heartdisease, restecg, exang)
# (thalach _|_ trestbps, age, fbs | sex, heartdisease, chol, restecg, exang)
# (thalach _|_ trestbps, exang, sex | age, fbs, heartdisease, chol, restecg)
# (thalach _|_ trestbps, sex, restecg | age, fbs, heartdisease, chol, exang)
# (thalach _|_ trestbps, chol, sex | age, fbs, heartdisease, restecg, exang)
# (thalach _|_ trestbps, fbs, sex | age, heartdisease, chol, restecg, exang)
# (thalach _|_ trestbps, age, sex | fbs, heartdisease, chol, restecg, exang)
# (thalach _|_ restecg, exang | trestbps, sex, age, fbs, heartdisease, chol)
# (thalach _|_ exang, chol | trestbps, sex, age, fbs, heartdisease, restecg)
# (thalach _|_ restecg, chol | trestbps, sex, age, fbs, heartdisease, exang)
# (thalach _|_ exang | trestbps, sex, age, fbs, chol, restecg)
# (thalach _|_ exang, fbs | trestbps, sex, age, heartdisease, chol, restecg)
# (thalach _|_ restecg, fbs | trestbps, sex, age, heartdisease, chol, exang)
# (thalach _|_ fbs, chol | trestbps, sex, age, heartdisease, restecg, exang)
# (thalach _|_ age, exang | trestbps, sex, fbs, heartdisease, chol, restecg)
# (thalach _|_ restecg, age | trestbps, sex, fbs, heartdisease, chol, exang)
# (thalach _|_ age, chol | trestbps, sex, fbs, heartdisease, restecg, exang)
# (thalach _|_ age | trestbps, sex, fbs, chol, restecg, exang)
# (thalach _|_ age, fbs | trestbps, sex, heartdisease, chol, restecg, exang)
# (thalach _|_ exang, sex | trestbps, age, fbs, heartdisease, chol, restecg)
# (thalach _|_ restecg, sex | trestbps, age, fbs, heartdisease, chol, exang)
# (thalach _|_ chol, sex | trestbps, age, fbs, heartdisease, restecg, exang)
# (thalach _|_ sex | trestbps, age, fbs, chol, restecg, exang)
# (thalach _|_ fbs, sex | trestbps, age, heartdisease, chol, restecg, exang)
# (thalach _|_ age, sex | trestbps, fbs, heartdisease, chol, restecg, exang)
# (thalach _|_ trestbps, exang | sex, age, fbs, heartdisease, chol, restecg)
# (thalach _|_ trestbps, restecg | sex, age, fbs, heartdisease, chol, exang)
# (thalach _|_ trestbps, chol | sex, age, fbs, heartdisease, restecg, exang)
# (thalach _|_ trestbps, fbs | sex, age, heartdisease, chol, restecg, exang)
# (thalach _|_ trestbps, age | sex, fbs, heartdisease, chol, restecg, exang)
# (thalach _|_ trestbps, sex | age, fbs, heartdisease, chol, restecg, exang)
# (thalach _|_ exang | trestbps, sex, age, fbs, heartdisease, chol, restecg)
# (thalach _|_ restecg | trestbps, sex, age, fbs, heartdisease, chol, exang)
# (thalach _|_ chol | trestbps, sex, age, fbs, heartdisease, restecg, exang)
# (thalach _|_ fbs | trestbps, sex, age, heartdisease, chol, restecg, exang)
# (thalach _|_ age | trestbps, sex, fbs, heartdisease, chol, restecg, exang)
# (thalach _|_ sex | trestbps, age, fbs, heartdisease, chol, restecg, exang)
# (thalach _|_ trestbps | sex, age, fbs, heartdisease, chol, restecg, exang)
# (chol _|_ trestbps, sex, thalach, restecg, age, exang, fbs | heartdisease)
# (chol _|_ exang, sex | trestbps, age)
# (chol _|_ age, exang, sex | trestbps, fbs)
# (chol _|_ sex, thalach, restecg, age, exang, fbs | trestbps, heartdisease)
# (chol _|_ trestbps, thalach, restecg, age, exang, fbs | heartdisease, sex)
# (chol _|_ trestbps, sex, thalach, restecg, exang, fbs | heartdisease, age)
# (chol _|_ trestbps, sex, thalach, restecg, age, exang | heartdisease, fbs)
# (chol _|_ trestbps, sex, restecg, age, exang, fbs | heartdisease, thalach)
# (chol _|_ trestbps, sex, thalach, age, exang, fbs | heartdisease, restecg)
# (chol _|_ trestbps, sex, thalach, restecg, age, fbs | heartdisease, exang)
# (chol _|_ exang | trestbps, age, sex)
# (chol _|_ age, exang | trestbps, fbs, sex)
# (chol _|_ thalach, restecg, age, exang, fbs | trestbps, sex, heartdisease)
# (chol _|_ exang, sex | trestbps, age, fbs)
# (chol _|_ sex, thalach, restecg, exang, fbs | trestbps, age, heartdisease)
# (chol _|_ exang, sex | trestbps, age, thalach)
# (chol _|_ exang, sex | trestbps, age, restecg)
# (chol _|_ sex | trestbps, age, exang)
# (chol _|_ sex, thalach, restecg, age, exang | trestbps, fbs, heartdisease)
# (chol _|_ age, exang, sex | trestbps, fbs, thalach)
# (chol _|_ age, exang, sex | trestbps, fbs, restecg)
# (chol _|_ age, sex | trestbps, exang, fbs)
# (chol _|_ sex, restecg, age, exang, fbs | trestbps, heartdisease, thalach)
# (chol _|_ sex, thalach, age, exang, fbs | trestbps, restecg, heartdisease)
# (chol _|_ sex, thalach, restecg, age, fbs | trestbps, exang, heartdisease)
# (chol _|_ trestbps, thalach, restecg, exang, fbs | heartdisease, age, sex)
# (chol _|_ trestbps, thalach, restecg, age, exang | heartdisease, fbs, sex)
# (chol _|_ trestbps, restecg, age, exang, fbs | heartdisease, sex, thalach)
# (chol _|_ trestbps, thalach, age, exang, fbs | heartdisease, restecg, sex)
# (chol _|_ trestbps, thalach, restecg, age, fbs | heartdisease, exang, sex)
# (chol _|_ trestbps, sex, thalach, restecg, exang | heartdisease, age, fbs)
# (chol _|_ trestbps, sex, restecg, exang, fbs | heartdisease, age, thalach)
# (chol _|_ trestbps, sex, thalach, exang, fbs | heartdisease, age, restecg)
# (chol _|_ trestbps, sex, thalach, restecg, fbs | heartdisease, age, exang)
# (chol _|_ trestbps, sex, restecg, age, exang | heartdisease, fbs, thalach)
# (chol _|_ trestbps, sex, thalach, age, exang | heartdisease, fbs, restecg)
# (chol _|_ trestbps, sex, thalach, restecg, age | heartdisease, exang, fbs)
# (chol _|_ trestbps, sex, age, exang, fbs | heartdisease, restecg, thalach)
# (chol _|_ trestbps, sex, restecg, age, fbs | heartdisease, exang, thalach)
# (chol _|_ trestbps, sex, thalach, age, fbs | heartdisease, exang, restecg)
# (chol _|_ exang | trestbps, age, fbs, sex)
# (chol _|_ restecg, exang, fbs, thalach | trestbps, age, sex, heartdisease)
# (chol _|_ exang | trestbps, age, sex, thalach)
# (chol _|_ exang | trestbps, age, restecg, sex)
# (chol _|_ restecg, age, exang, thalach | trestbps, fbs, sex, heartdisease)
# (chol _|_ age, exang | trestbps, fbs, sex, thalach)
# (chol _|_ age, exang | trestbps, restecg, fbs, sex)
# (chol _|_ age | trestbps, exang, fbs, sex)
# (chol _|_ restecg, age, exang, fbs | trestbps, thalach, sex, heartdisease)
# (chol _|_ age, exang, fbs, thalach | trestbps, restecg, sex, heartdisease)
# (chol _|_ restecg, age, fbs, thalach | trestbps, exang, sex, heartdisease)
# (chol _|_ restecg, exang, sex, thalach | trestbps, age, fbs, heartdisease)
# (chol _|_ exang, sex | trestbps, age, fbs, thalach)
# (chol _|_ exang, sex | trestbps, age, fbs, restecg)
# (chol _|_ sex | trestbps, age, exang, fbs)
# (chol _|_ restecg, exang, fbs, sex | trestbps, age, heartdisease, thalach)
# (chol _|_ exang, fbs, sex, thalach | trestbps, age, restecg, heartdisease)
# (chol _|_ restecg, fbs, sex, thalach | trestbps, age, exang, heartdisease)
# (chol _|_ exang, sex | trestbps, age, restecg, thalach)
# (chol _|_ sex | trestbps, age, exang, thalach)
# (chol _|_ sex | trestbps, age, exang, restecg)
# (chol _|_ restecg, age, exang, sex | trestbps, fbs, heartdisease, thalach)
# (chol _|_ age, exang, sex, thalach | trestbps, restecg, fbs, heartdisease)
# (chol _|_ restecg, age, sex, thalach | trestbps, exang, fbs, heartdisease)
# (chol _|_ age, exang, sex | trestbps, fbs, restecg, thalach)
# (chol _|_ age, sex | trestbps, exang, fbs, thalach)
# (chol _|_ age, sex | trestbps, exang, fbs, restecg)
# (chol _|_ age, exang, fbs, sex | trestbps, restecg, heartdisease, thalach)
# (chol _|_ restecg, age, fbs, sex | trestbps, exang, heartdisease, thalach)
# (chol _|_ age, fbs, sex, thalach | trestbps, exang, restecg, heartdisease)
# (chol _|_ trestbps, exang, restecg, thalach | heartdisease, age, fbs, sex)
# (chol _|_ trestbps, exang, fbs, restecg | heartdisease, age, sex, thalach)
# (chol _|_ trestbps, exang, fbs, thalach | heartdisease, age, restecg, sex)
# (chol _|_ trestbps, fbs, restecg, thalach | heartdisease, age, exang, sex)
# (chol _|_ trestbps, age, exang, restecg | heartdisease, fbs, sex, thalach)
# (chol _|_ trestbps, age, exang, thalach | heartdisease, restecg, fbs, sex)
# (chol _|_ trestbps, age, restecg, thalach | heartdisease, exang, fbs, sex)
# (chol _|_ trestbps, age, exang, fbs | heartdisease, restecg, sex, thalach)
# (chol _|_ trestbps, age, fbs, restecg | heartdisease, exang, sex, thalach)
# (chol _|_ trestbps, age, fbs, thalach | heartdisease, exang, restecg, sex)
# (chol _|_ trestbps, exang, sex, restecg | heartdisease, age, fbs, thalach)
# (chol _|_ trestbps, exang, sex, thalach | heartdisease, age, fbs, restecg)
# (chol _|_ trestbps, sex, restecg, thalach | heartdisease, age, exang, fbs)
# (chol _|_ trestbps, exang, fbs, sex | heartdisease, age, restecg, thalach)
# (chol _|_ trestbps, fbs, sex, restecg | heartdisease, age, exang, thalach)
# (chol _|_ trestbps, fbs, sex, thalach | heartdisease, age, exang, restecg)
# (chol _|_ trestbps, age, exang, sex | heartdisease, fbs, restecg, thalach)
# (chol _|_ trestbps, age, sex, restecg | heartdisease, exang, fbs, thalach)
# (chol _|_ trestbps, age, sex, thalach | heartdisease, exang, fbs, restecg)
# (chol _|_ trestbps, age, fbs, sex | heartdisease, exang, restecg, thalach)
# (chol _|_ restecg, exang, thalach | trestbps, sex, age, fbs, heartdisease)
# (chol _|_ exang | trestbps, sex, age, fbs, thalach)
# (chol _|_ exang | trestbps, sex, age, fbs, restecg)
# (chol _|_ restecg, exang, fbs | trestbps, sex, age, heartdisease, thalach)
# (chol _|_ exang, fbs, thalach | trestbps, sex, age, heartdisease, restecg)
# (chol _|_ restecg, fbs, thalach | trestbps, sex, age, heartdisease, exang)
# (chol _|_ exang | trestbps, sex, age, thalach, restecg)
# (chol _|_ restecg, age, exang | trestbps, sex, fbs, heartdisease, thalach)
# (chol _|_ age, exang, thalach | trestbps, sex, fbs, heartdisease, restecg)
# (chol _|_ restecg, age, thalach | trestbps, sex, fbs, heartdisease, exang)
# (chol _|_ age, exang | trestbps, sex, fbs, thalach, restecg)
# (chol _|_ age | trestbps, sex, fbs, thalach, exang)
# (chol _|_ age | trestbps, sex, fbs, restecg, exang)
# (chol _|_ age, exang, fbs | trestbps, sex, heartdisease, thalach, restecg)
# (chol _|_ restecg, age, fbs | trestbps, sex, heartdisease, thalach, exang)
# (chol _|_ age, fbs, thalach | trestbps, sex, heartdisease, restecg, exang)
# (chol _|_ restecg, exang, sex | trestbps, age, fbs, heartdisease, thalach)
# (chol _|_ exang, sex, thalach | trestbps, age, fbs, heartdisease, restecg)
# (chol _|_ restecg, sex, thalach | trestbps, age, fbs, heartdisease, exang)
# (chol _|_ exang, sex | trestbps, age, fbs, thalach, restecg)
# (chol _|_ sex | trestbps, age, fbs, thalach, exang)
# (chol _|_ sex | trestbps, age, fbs, restecg, exang)
# (chol _|_ exang, fbs, sex | trestbps, age, heartdisease, thalach, restecg)
# (chol _|_ restecg, fbs, sex | trestbps, age, heartdisease, thalach, exang)
# (chol _|_ fbs, sex, thalach | trestbps, age, heartdisease, restecg, exang)
# (chol _|_ sex | trestbps, age, thalach, restecg, exang)
# (chol _|_ age, exang, sex | trestbps, fbs, heartdisease, thalach, restecg)
# (chol _|_ restecg, age, sex | trestbps, fbs, heartdisease, thalach, exang)
# (chol _|_ age, sex, thalach | trestbps, fbs, heartdisease, restecg, exang)
# (chol _|_ age, sex | trestbps, fbs, thalach, restecg, exang)
# (chol _|_ age, fbs, sex | trestbps, heartdisease, thalach, restecg, exang)
# (chol _|_ trestbps, exang, restecg | sex, age, fbs, heartdisease, thalach)
# (chol _|_ trestbps, exang, thalach | sex, age, fbs, heartdisease, restecg)
# (chol _|_ trestbps, restecg, thalach | sex, age, fbs, heartdisease, exang)
# (chol _|_ trestbps, exang, fbs | sex, age, heartdisease, thalach, restecg)
# (chol _|_ trestbps, fbs, restecg | sex, age, heartdisease, thalach, exang)
# (chol _|_ trestbps, fbs, thalach | sex, age, heartdisease, restecg, exang)
# (chol _|_ trestbps, age, exang | sex, fbs, heartdisease, thalach, restecg)
# (chol _|_ trestbps, age, restecg | sex, fbs, heartdisease, thalach, exang)
# (chol _|_ trestbps, age, thalach | sex, fbs, heartdisease, restecg, exang)
# (chol _|_ trestbps, age, fbs | sex, heartdisease, thalach, restecg, exang)
# (chol _|_ trestbps, exang, sex | age, fbs, heartdisease, thalach, restecg)
# (chol _|_ trestbps, sex, restecg | age, fbs, heartdisease, thalach, exang)
# (chol _|_ trestbps, sex, thalach | age, fbs, heartdisease, restecg, exang)
# (chol _|_ trestbps, fbs, sex | age, heartdisease, thalach, restecg, exang)
# (chol _|_ trestbps, age, sex | fbs, heartdisease, thalach, restecg, exang)
# (chol _|_ restecg, exang | trestbps, sex, age, fbs, heartdisease, thalach)
# (chol _|_ exang, thalach | trestbps, sex, age, fbs, heartdisease, restecg)
# (chol _|_ restecg, thalach | trestbps, sex, age, fbs, heartdisease, exang)
# (chol _|_ exang | trestbps, sex, age, fbs, thalach, restecg)
# (chol _|_ exang, fbs | trestbps, sex, age, heartdisease, thalach, restecg)
# (chol _|_ restecg, fbs | trestbps, sex, age, heartdisease, thalach, exang)
# (chol _|_ fbs, thalach | trestbps, sex, age, heartdisease, restecg, exang)
# (chol _|_ age, exang | trestbps, sex, fbs, heartdisease, thalach, restecg)
# (chol _|_ restecg, age | trestbps, sex, fbs, heartdisease, thalach, exang)
# (chol _|_ age, thalach | trestbps, sex, fbs, heartdisease, restecg, exang)
# (chol _|_ age | trestbps, sex, fbs, thalach, restecg, exang)
# (chol _|_ age, fbs | trestbps, sex, heartdisease, thalach, restecg, exang)
# (chol _|_ exang, sex | trestbps, age, fbs, heartdisease, thalach, restecg)
# (chol _|_ restecg, sex | trestbps, age, fbs, heartdisease, thalach, exang)
# (chol _|_ sex, thalach | trestbps, age, fbs, heartdisease, restecg, exang)
# (chol _|_ sex | trestbps, age, fbs, thalach, restecg, exang)
# (chol _|_ fbs, sex | trestbps, age, heartdisease, thalach, restecg, exang)
# (chol _|_ age, sex | trestbps, fbs, heartdisease, thalach, restecg, exang)
# (chol _|_ trestbps, exang | sex, age, fbs, heartdisease, thalach, restecg)
# (chol _|_ trestbps, restecg | sex, age, fbs, heartdisease, thalach, exang)
# (chol _|_ trestbps, thalach | sex, age, fbs, heartdisease, restecg, exang)
# (chol _|_ trestbps, fbs | sex, age, heartdisease, thalach, restecg, exang)
# (chol _|_ trestbps, age | sex, fbs, heartdisease, thalach, restecg, exang)
# (chol _|_ trestbps, sex | age, fbs, heartdisease, thalach, restecg, exang)
# (chol _|_ exang | trestbps, sex, age, fbs, heartdisease, thalach, restecg)
# (chol _|_ restecg | trestbps, sex, age, fbs, heartdisease, thalach, exang)
# (chol _|_ thalach | trestbps, sex, age, fbs, heartdisease, restecg, exang)
# (chol _|_ fbs | trestbps, sex, age, heartdisease, thalach, restecg, exang)
# (chol _|_ age | trestbps, sex, fbs, heartdisease, thalach, restecg, exang)
# (chol _|_ sex | trestbps, age, fbs, heartdisease, thalach, restecg, exang)
# (chol _|_ trestbps | sex, age, fbs, heartdisease, thalach, restecg, exang)

# %%
from pgmpy.inference import VariableElimination

# %%
HeartDisease_infer=VariableElimination(model)

# %%
q=HeartDisease_infer.query(variables=['heartdisease'],evidence={'age':28})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5770 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4230 │
# ╘════════════════╧═════════════════════╛

# %%
q=HeartDisease_infer.query(variables=['heartdisease'],evidence={'chol':100})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5510 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4490 │
# ╘════════════════╧═════════════════════╛
